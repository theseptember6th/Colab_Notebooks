# %%
# !rm -rf *

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.6/913.6 kB 53.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model=YOLO('yolov8x')
results=model.predict('/content/drive/MyDrive/SoccerAnalysis/input_images/image1.png',save=True)
print(results[0])
for box in results[0].boxes:
  print(box)
# Out:
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 381MB/s]
# image 1/1 /content/drive/MyDrive/SoccerAnalysis/input_images/image1.png: 384x640 23 persons, 1 tv, 126.9ms
# Speed: 12.9ms preprocess, 126.9ms inference, 1046.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...
