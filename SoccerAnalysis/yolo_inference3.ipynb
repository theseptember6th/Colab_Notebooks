# %%
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.6/913.6 kB 23.6 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
model=YOLO('/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/yolov8x.pt')
results=model.predict('/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/input_videos/08fd33_4.mp4',save=True)
print(results[0])
for box in results[0].boxes:
  print(box)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# ...

# %%
import shutil

source_folder='/content/runs/detect/predict'
destination_folder='/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/runs/detect/predict2'
shutil.copytree(source_folder,destination_folder)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/runs/detect/predict2'
