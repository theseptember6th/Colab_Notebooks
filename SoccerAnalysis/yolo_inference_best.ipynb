# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="utMzOzqtddLJe4EHq9uU")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov8:: 100%|██████████| 1338/1338 [00:00<00:00, 2607.35it/s]

# %%
import shutil
source_folder='/content/datasets'
destination_folder='/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/datasets'
shutil.copytree(source_folder,destination_folder)
# Out:
# '/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/datasets'

# %%
# !pip install ultralytics -q

# %%
from ultralytics import YOLO
model=YOLO('/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/yolov8x.pt').to('cuda')
results=model.train(data='/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/datasets/data.yaml',epochs=10,imgsz=640,mode='detect')
# Out:
# engine/trainer: task=detect, mode=train, model=/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/yolov8x.pt, data=/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/datasets/data.yaml, epochs=10, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cuda:0, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, sho
# ...

# %%
import shutil
shutil.copytree('/content/runs/detect/train2/weights','/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/model')
# Out:
# '/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/model'

# %%
from ultralytics import YOLO
model=YOLO('/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/model/best.pt')
#video
results=model.predict('/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/input_videos/08fd33_4.mp4',save=True)
#image
results1=model.predict('/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/input_images/image1.png',save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/input_videos/08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 21 players, 3 referees, 88.6ms
# video 1/1 (frame 2/750) /content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/input_videos/08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 21 players, 3 referees, 53.5ms
# ...

# %%
import shutil
shutil.copytree('/content/runs/detect/predict','/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/runs/detect/predict3(Best)')
# Out:
# '/content/drive/MyDrive/Colab Notebooks/SoccerAnalysis/runs/detect/predict3(Best)'
